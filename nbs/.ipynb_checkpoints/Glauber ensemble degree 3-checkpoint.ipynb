# %%
using Plots
include("../ensemble.jl")
include("../exact/random_regular.jl")
import ProgressMeter; ProgressMeter.ijulia_behavior(:clear);

# %% [markdown]
# ## β=1.0
# This is above the ferromagnetic transition @ $β=\tanh^{-1}\left(\frac{1}{J(k-1)}\right)\approx 0.5$

# %%
β = 1.0
T = 25     # final time
ε = 5e-2  # truncation error for svd   
pᵢ⁰ = [0.75, 0.25]   # initial condition: magnetization = +0.5
ϕᵢ = [ones(2) for _ in 1:T]   # observations (none)
wᵢ = fill( GlauberFactor(ones(2), 0.0, β), T )   # transition probabilities: J=1, h=0

A = mpem2(2, T, d=1)   # initialize with bonds of dimension d
Δs = zeros(0);

# %% [markdown]
# Run on infinite 3-regular graph

# %%
A, iters, Δs = iterate_rs_deg3(A, pᵢ⁰, ϕᵢ; ε, maxiter=100, tol=1e-3, Δs, verbose=true, showprogress=false)
println("### Computing magnetization...\n")
mag = magnetization_rs_deg3(A, pᵢ⁰, ϕᵢ; ε);
# Out:
# Converting B to C 100%|██████████████████████████████████| Time: 0:00:30
#   t:  25/25
# 26-element Vector{Float64}:
#  0.6453610076753926
#  0.6898876328472534
#  0.7022689877581129
#  0.7093490821414807
#  0.7008391163901979
#  0.7088855384890915
#  0.6862214964257805
#  0.6897438332476067
#  0.664647303342617
#  0.6660408206716901
#  0.6421397891609886
#  0.6414944581755551
#  0.6187594504360754
#  0.6156035219182041
#  0.6026176139724075
#  0.5982592751481934
#  0.5880600112516201
#  0.5838504249352214
#  0.5746944376710132
#  0.5695474701565995
#  0.5603824247071908
#  0.5458288510290411
#  0.536296233785944
#  0.5201047936907031
#  0.4911409912722679
#  0.4639900842830902

# %% [markdown]
# Compute RS equilibrium prediction

# %%
k = 3
J = 1.0
m_eq = rs_magnetization_fixedpoints(β, J, k)
# Out:
# 3-element Vector{Float64}:
#  -0.9497414964253968
#   0.0
#   0.9497414964253968

# %%
p1 = plot(0:T, mag, title="T=$T, β=$β, ε=$ε", xlabel="time",
    ylabel="magnetiz", m=:o, label="", titlefontsize=12)
hline!(p1, [m_eq[3]], ls=:dash, label="RS @equilibrium")
p2 = plot(1:iters, Δs[1:iters], xlabel="time", ylabel="convergence error", 
    m=:o, label="")
p3 = plot(p1, p2, layout=(2,1), size=(500,500))

# %% [markdown]
# As it should be:

# %% [markdown]
# ![image.png](attachment:image.png)
