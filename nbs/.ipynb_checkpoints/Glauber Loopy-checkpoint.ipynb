# %%
using Graphs
using Plots
using LinearAlgebra
using Statistics
include("../mpdbp.jl")
include("../exact/random_regular.jl")
import ProgressMeter; ProgressMeter.ijulia_behavior(:append);

# %% [markdown]
# BP on a tetrahedron graph

# %%
q = q_glauber
T = 7
N = 4
J = ones(N,N) - diagm(ones(N))
h = zeros(N)
β = 1.0
ising = Ising(J, h, β)

p⁰ = map(1:N) do i
    r = 0.75
    [r, 1-r]
end
ϕ = [[[0.5,0.5] for t in 1:T] for i in 1:N];

# %%
bp = mpdbp(ising, T, ϕ, p⁰, d=1)
cb = CB_BP(bp);

# %%
ε = 1e-3
iterate!(bp, maxiter=100; ε, cb, tol=1e-3);
# Out:
# Running MPdBP: iter 2 	 Time: 0:11:28
# Running MPdBP: iter 3 	 Time: 0:23:23
# Running MPdBP: iter 4 	 Time: 0:29:31
# Running MPdBP: iter 5 	 Time: 0:34:58
# Running MPdBP: iter 6 	 Time: 0:40:16
#   Δ:  0.05220807882002515WARNING: Force throwing a SIGINT
# InterruptException:
#
# Stacktrace:
#   [1] ==
#     @ ./promotion.jl:477 [inlined]
#   [2] iterate
#     @ ./range.jl:883 [inlined]
#   [3] 𝒜𝒸𝓉!
#     @ ~/.julia/packages/Tullio/NGyNM/src/macro.jl:1211 [inlined]
#   [4] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Nothing)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:139
#   [5] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Nothing) (repeats 2 times)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:142
#   [6] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:146
#   [7] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:143
#   [8] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:142
#   [9] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:147
#  [10] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:143
#  [11] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:142
#  [12] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:147
#  [13] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool) (repeats 2 times)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:143
#  [14] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:147
#  [15] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Bool, final::Bool) (repeats 2 times)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:143
#  [16] tile_halves(fun!::var"#𝒜𝒸𝓉!#1379", ::Type{Array{Float64}}, As::Tuple{Array{Float64, 5}, Vector{Float64}, Array{Float64, 3}, Array{Float64, 5}}, Is::NTuple{5, UnitRange{Int64}}, Js::Tuple{UnitRange{Int64}}, keep::Nothing, final::Bool)
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/threads.jl:147
#  [17] tile_halves
#     @ ~/.julia/packages/Tullio/NGyNM/src/threads.jl:136 [inlined]
#  [18] threader
#     @ ~/.julia/packages/Tullio/NGyNM/src/threads.jl:65 [inlined]
#  [19] (::var"#ℳ𝒶𝓀ℯ#1382"{var"#𝒜𝒸𝓉!#1379"})(λ::Vector{Float64}, Vt::Array{Float64, 3}, Bᵗ⁺¹::Array{Float64, 5})
#     @ Main ~/.julia/packages/Tullio/NGyNM/src/macro.jl:807
#  [20] (::Tullio.Eval{var"#ℳ𝒶𝓀ℯ#1382"{var"#𝒜𝒸𝓉!#1379"}, var"#1071#∇ℳ𝒶𝓀ℯ#1381"{var"#∇𝒜𝒸𝓉!#1380"}})(::Vector{Float64}, ::Vararg{Any})
#     @ Tullio ~/.julia/packages/Tullio/NGyNM/src/eval.jl:20
#  [21] mpem2(B::MPEM3{2, 8, Float64}; showprogress::Bool)
#     @ Main ~/MPdBP/mpem3.jl:73
#  [22] mpem2(B::MPEM3{2, 8, Float64})
#     @ Main ~/MPdBP/mpem3.jl:55
#  [23] belief(bp::MPdBP{2, 8, Float64, GlauberFactor{Float64}}, i::Int64; ε::Float64)
#     @ Main ~/MPdBP/mpdbp.jl:100
#  [24] (::var"#1510#1511"{Float64, MPdBP{2, 8, Float64, GlauberFactor{Float64}}})(i::Int64)
#     @ Main ~/MPdBP/mpdbp.jl:112
#  [25] iterate
#     @ ./generator.jl:47 [inlined]
#  [26] _collect(c::UnitRange{Int64}, itr::Base.Generator{UnitRange{Int64}, var"#1510#1511"{Float64, MPdBP{2, 8, Float64, GlauberFactor{Float64}}}}, #unused#::Base.EltypeUnknown, isz::Base.HasShape{1})
#     @ Base ./array.jl:807
#  [27] collect_similar
#     @ ./array.jl:716 [inlined]
#  [28] map
#     @ ./abstractarray.jl:2933 [inlined]
#  [29] #magnetizations#1509
#     @ ~/MPdBP/mpdbp.jl:111 [inlined]
#  [30] magnetizations
#     @ ~/MPdBP/mpdbp.jl:109 [inlined]
#  [31] (::CB_BP{ProgressUnknown})(bp::MPdBP{2, 8, Float64, GlauberFactor{Float64}}, it::Int64)
#     @ Main ~/MPdBP/mpdbp.jl:74
#  [32] iterate!(bp::MPdBP{2, 8, Float64, GlauberFactor{Float64}}; maxiter::Int64, ε::Float64, cb::CB_BP{ProgressUnknown}, tol::Float64, nodes::Vector{Int64})
#     @ Main ~/MPdBP/mpdbp.jl:89
#  [33] top-level scope
#     @ In[60]:2
#  [34] eval
#     @ ./boot.jl:368 [inlined]
#  [35] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1428

# %%
m_bp = cb.mag[end]
pl = plot(0:T, mean(m_bp), xlabel="time", ylabel="magnetization", m=:o, size=(400,400),
    xticks=0:2:T, label="BP tetrahedron")
m_eq = rs_magnetization_fixedpoints(β, 1.0, 3)
hline!([m_eq[3]], ls=:dash, label="RS @equilibrium", legend=:bottomright, title="matrix product on tetrahedron")
pl_err = plot(cb.Δs, ylabel="convergence error", xlabel="iters", m=:o, yaxis=:log10)
plot(pl, pl_err)

# %% [markdown]
# Observe magnetiz over BP iterations

# %%
using ColorSchemes
cg = cgrad(:matter, length(cb.mag), categorical=true)
pll = plot(xlabel="time", ylabel="magnetiz",legend=:outertopright)
for i in reverse( eachindex(cb.mag) )
    plot!(pll, 0:T, mean(cb.mag[i]), c=cg[i], label="iter $i", m=:o)
end
plot(pll, size=(400,300))

# %% [markdown]
# ## Use messages as starting point for RS

# %%
include("../ensemble.jl")
# Out:
# magnetization_rs_deg3 (generic function with 1 method)

# %%
A = deepcopy(bp.μ[1])
pᵢ⁰ = p⁰[1]
ϕᵢ = ϕ[1]
wᵢ = fill( GlauberFactor(ones(3), 0.0, β), T )
ε = 1e-3
# Out:
# 0.001

# %%
Δs = zeros(0)
A, iters, Δs = iterate_rs_deg3(A, pᵢ⁰, wᵢ, ϕᵢ; ε, maxiter=100, tol=1e-3, Δs, verbose=true, showprogress=false)
println("### Computing magnetization...\n")
mag = magnetization_rs_deg3(A, pᵢ⁰, wᵢ, ϕᵢ; ε);
# Out:
# ### iter 1 of 100
# Δ: 0.0009621902597698462 / 0.001
# bonds:	[4, 10, 12, 12, 12, 11, 6, 2]
#
# ### Computing magnetization...
# Computing belief  29%|██████████                         |  ETA: 0:00:03
# 4m  t:  2/8
# Computing belief  43%|███████████████                    |  ETA: 0:00:04
# 4m  t:  3/8
# Computing belief  57%|████████████████████               |  ETA: 0:00:04
# 4m  t:  4/8
# Computing belief  71%|█████████████████████████          |  ETA: 0:00:03
# 4m  t:  5/8
# Computing belief 100%|███████████████████████████████████| Time: 0:00:06
#   t:  7/8
# Converting B to C  38%|████████████▊                     |  ETA: 0:00:04
# 4m  t:  3/8
# Converting B to C  50%|█████████████████                 |  ETA: 0:00:13
# 4m  t:  4/8
# Converting B to C  62%|█████████████████████▎            |  ETA: 0:00:32
# 4m  t:  5/8
# Converting B to C  75%|█████████████████████████▌        |  ETA: 0:00:23
# 4m  t:  6/8
# Converting B to C 100%|██████████████████████████████████| Time: 0:01:09
#   t:  8/8

# %%
plot!(deepcopy(pl), 0:T, mag, label="matrix product RS", m=:o, title="Random regular k=3")
