# %%
using Graphs
using Plots
using LinearAlgebra
using Statistics
using DelimitedFiles
include("../mpdbp.jl")
include("../exact/random_regular.jl")
include("../glauber.jl")
import ProgressMeter; ProgressMeter.ijulia_behavior(:append);

# %% [markdown]
# BP on a tetrahedron graph

# %%
q = q_glauber
T = 6
N = 4
J = ones(N,N) - diagm(ones(N))
h = zeros(N)
β = 1.0
ising = Ising(J, h, β)

p⁰ = map(1:N) do i
    r = 0.75
    [r, 1-r]
    end;

# %%
bp = mpdbp(ising, T; p⁰, d=1)
cb = CB_BP(bp);

# %%
svd_trunc = TruncThresh(1e-2)
# svd_trunc = TruncBond(5)
iterate!(bp, maxiter=100; svd_trunc, cb, tol=1e-3);
# Out:
# Running MPdBP: iter 2 	 Time: 0:00:22
# Running MPdBP: iter 3 	 Time: 0:00:23
# Running MPdBP: iter 4 	 Time: 0:00:24
# Running MPdBP: iter 5 	 Time: 0:00:25
# Running MPdBP: iter 6 	 Time: 0:00:26
#   Δ:  0.0008745678687577807

# %%
pl_err = plot(cb.Δs, ylabel="convergence error", xlabel="iters", m=:o, yaxis=:log10, 
    size=(300,200), label="")

# %%
b_bp = beliefs(bp)
m_bp = [[bbb[1]-bbb[2] for bbb in bb] for bb in b_bp]
pl = plot(0:T, mean(m_bp), xlabel="time", ylabel="magnetization", m=:o, size=(400,400),
    xticks=0:2:T, label="BP tetrahedron")
ff = readdlm("montecarlo_N1000.txt", Float64)
plot!(pl, ff[1:T+1,1], ff[1:T+1,2], label="Monte Carlo", m=:diamond)
pl

# %% [markdown]
# Observe magnetiz over BP iterations

# %%
using ColorSchemes
cg = cgrad(:matter, length(cb.mag), categorical=true)
pll = plot(xlabel="time", ylabel="magnetiz",legend=:outertopright)
for i in reverse( eachindex(cb.mag) )
    plot!(pll, 0:T, mean(cb.mag[i]), c=cg[i], label="iter $i", m=:o)
end
plot(pll, size=(400,300))

# %% [markdown]
# ## Use messages as starting point for RS

# %%
include("../ensemble.jl")
# Out:
# magnetization_rs_deg3 (generic function with 1 method)

# %%
A = deepcopy(bp.μ[1])
pᵢ⁰ = p⁰[1]
ϕᵢ = ϕ[1]
wᵢ = fill( GlauberFactor(ones(3), 0.0, β), T )
svd_trunc = TruncThresh(1e-3)
# Out:
# TruncThresh{Float64}(0.001)

# %%
Δs = zeros(0)
A, iters, Δs = iterate_rs_deg3(A, pᵢ⁰, wᵢ, ϕᵢ; svd_trunc, maxiter=100, tol=1e-3, Δs, verbose=true, showprogress=false)
println("### Computing magnetization...\n")
mag = magnetization_rs_deg3(A, pᵢ⁰, wᵢ, ϕᵢ; svd_trunc);
# Out:
# ### iter 1 of 100
# Δ: 0.005372201217900052 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
#
# ### iter 2 of 100
# Δ: 0.006101524108183987 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
#
# ### iter 3 of 100
# Δ: 0.0037989757783495337 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
#
# ### iter 4 of 100
# Δ: 0.004067576462200739 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
#
# ### iter 5 of 100
# Δ: 0.002978536147019595 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
#
# ### iter 6 of 100
# Δ: 0.0021913995707389944 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
#
# ### iter 7 of 100
# Δ: 0.0015509280741351494 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
#
# ### iter 8 of 100
# Δ: 0.0009094686335411328 / 0.001
# bonds:	[4, 10, 12, 11, 6, 2]
#
# ### Computing magnetization...
# Computing belief  40%|██████████████                     |  ETA: 0:00:03
# 4m  t:  2/6
# Computing belief  60%|█████████████████████              |  ETA: 0:00:02
# 4m  t:  3/6
# Computing belief 100%|███████████████████████████████████| Time: 0:00:03
#   t:  5/6
# Converting B to C  50%|█████████████████                 |  ETA: 0:00:02
# 4m  t:  3/6
# Converting B to C  83%|████████████████████████████▍     |  ETA: 0:00:01
# 4m  t:  5/6
# Converting B to C 100%|██████████████████████████████████| Time: 0:00:02
#   t:  6/6

# %%
plot!(deepcopy(pl), 0:T, mag, label="matrix product RS", m=:o, title="Random regular k=3",
    legend=:bottomright, size=(500,500))
